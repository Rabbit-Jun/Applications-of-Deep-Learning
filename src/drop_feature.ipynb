# %%
import pandas as pd
filename=['arm_posture_errors',  'chest_and_hip_joint_errors',  'hip_joint_movement_errors', 'normal']
train_file_path = f'../data/train/{filename[0]}/CA01_Motion2-1.csv'
val_file_path = f'../data/val/{filename[0]}/CA02_Motion2-1.csv'

train_df = pd.read_csv(train_file_path)
val_df = pd.read_csv(val_file_path)

# %%
train_df.columns
# Out:
# Index(['image_filename', 'Nose_x', 'Nose_y', 'LEye_x', 'LEye_y', 'REye_x',
#        'REye_y', 'LEar_x', 'LEar_y', 'REar_x', 'REar_y', 'LShoulder_x',
#        'LShoulder_y', 'RShoulder_x', 'RShoulder_y', 'LElbow_x', 'LElbow_y',
#        'RElbow_x', 'RElbow_y', 'LWrist_x', 'LWrist_y', 'RWrist_x', 'RWrist_y',
#        'LHip_x', 'LHip_y', 'RHip_x', 'RHip_y', 'LKnee_x', 'LKnee_y', 'RKnee_x',
#        'RKnee_y', 'LAnkle_x', 'LAnkle_y', 'RAnkle_x', 'RAnkle_y', 'Head_x',
#        'Head_y', 'Neck_x', 'Neck_y', 'Hip_x', 'Hip_y', 'LBigToe_x',
#        'LBigToe_y', 'RBigToe_x', 'RBigToe_y', 'LSmallToe_x', 'LSmallToe_y',
#        'RSmallToe_x', 'RSmallToe_y', 'LHeel_x', 'LHeel_y', 'RHeel_x',
#        'RHeel_y'],
#       dtype='object')

# %%
val_df.columns
# Out:
# Index(['image_filename', 'Nose_x', 'Nose_y', 'LEye_x', 'LEye_y', 'REye_x',
#        'REye_y', 'LEar_x', 'LEar_y', 'REar_x', 'REar_y', 'LShoulder_x',
#        'LShoulder_y', 'RShoulder_x', 'RShoulder_y', 'LElbow_x', 'LElbow_y',
#        'RElbow_x', 'RElbow_y', 'LWrist_x', 'LWrist_y', 'RWrist_x', 'RWrist_y',
#        'LHip_x', 'LHip_y', 'RHip_x', 'RHip_y', 'LKnee_x', 'LKnee_y', 'RKnee_x',
#        'RKnee_y', 'LAnkle_x', 'LAnkle_y', 'RAnkle_x', 'RAnkle_y', 'Head_x',
#        'Head_y', 'Neck_x', 'Neck_y', 'Hip_x', 'Hip_y', 'LBigToe_x',
#        'LBigToe_y', 'RBigToe_x', 'RBigToe_y', 'LSmallToe_x', 'LSmallToe_y',
#        'RSmallToe_x', 'RSmallToe_y', 'LHeel_x', 'LHeel_y', 'RHeel_x',
#        'RHeel_y'],
#       dtype='object')

# %%
train_df.head(5)
# Out:
#   image_filename       Nose_x      Nose_y      LEye_x      LEye_y  \
# 0          0.jpg  1041.557129  330.939728  986.476318  320.925049
# 1          1.jpg  1041.385620  331.903595  991.370972  316.899200
# 2          2.jpg  1041.617676  334.954712  986.369263  319.886963
# 3          3.jpg  1041.478271  331.779449  991.494141  316.784210
# 4          4.jpg  1041.614502  331.018829  986.570496  321.010834
#
#         REye_x      REye_y      LEar_x      LEar_y       REar_x  ...  \
# 0  1041.557129  325.932373  986.476318  325.932373  1046.564453  ...
# 1  1041.385620  326.902130  986.369507  326.902130  1046.387085  ...
# 2  1041.617676  324.909546  986.369263  324.909546  1046.640259  ...
# 3  1041.478271  326.781036  986.495728  326.781036  1046.476685  ...
# 4  1041.614502  326.014832  986.570496  326.014832  1046.618530  ...
#
#      RBigToe_x   RBigToe_y  LSmallToe_x  LSmallToe_y  RSmallToe_x  \
# 0  1056.579224  726.520142   941.410217   731.527527  1066.593872
# ...

# %%
print(f'train_df.columns: {len(train_df.columns)}')
print(f'val_df.columns: {len(val_df.columns)}')
# Out:
# train_df.columns: 53
# val_df.columns: 53

# %%
print(f'len(train_df): {len(train_df)}')
print(f'len(val_df): {len(val_df)}')
# Out:
# len(train_df): 263
# len(val_df): 398

# %%
import os
import glob
import shutil


filename = ['arm_posture_errors', 'chest_and_hip_joint_errors', 'hip_joint_movement_errors', 'normal']
train_paths = [f'../data/train/{file}/*.csv' for file in filename]
train_data_path = '../data/train'
csv_files = []
for path in train_paths:
    csv_files.extend(glob.glob(path))

for file_path in csv_files:
    parts = file_path.split('/')
    label = parts[3]
    original_filename = parts[4]

    new_filename = f"{label}@{original_filename}"
    print(os.path.dirname(file_path))


    new_file_path = os.path.join(train_data_path, new_filename)

    shutil.move(file_path, new_file_path)
# Out:
# ../data/train/arm_posture_errors
# ../data/train/arm_posture_errors
# ../data/train/arm_posture_errors
# ../data/train/arm_posture_errors
# ../data/train/arm_posture_errors
# ../data/train/arm_posture_errors
# ../data/train/arm_posture_errors
# ../data/train/arm_posture_errors
# ../data/train/arm_posture_errors
# ../data/train/arm_posture_errors
# ../data/train/arm_posture_errors
# ../data/train/arm_posture_errors
# ../data/train/arm_posture_errors
# ../data/train/arm_posture_errors
# ../data/train/arm_posture_errors
# ../data/train/arm_posture_errors
# ../data/train/arm_posture_errors
# ../data/train/arm_posture_errors
# ../data/train/arm_posture_errors
# ../data/train/arm_posture_errors
# ../data/train/arm_posture_errors
# ../data/train/arm_posture_errors
# ../data/train/arm_posture_errors
# ../data/train/arm_posture_errors
# ../data/train/arm_posture_errors
# ../data/train/arm_posture_errors
# ../data/train/arm_posture_errors
# ../data/train/arm_posture_errors
# ...

# %%
import os
import glob
import shutil


filename = ['arm_posture_errors', 'chest_and_hip_joint_errors', 'hip_joint_movement_errors', 'normal']
val_paths = [f'../data/val/{file}/*.csv' for file in filename]
val_data_path = '../data/val'
csv_files = []
for path in val_paths:
    csv_files.extend(glob.glob(path))

for file_path in csv_files:
    parts = file_path.split('/')
    label = parts[3]
    original_filename = parts[4]

    new_filename = f"{label}@{original_filename}"
    print(os.path.dirname(file_path))


    new_file_path = os.path.join(val_data_path, new_filename)

    shutil.move(file_path, new_file_path)
# Out:
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ../data/val/arm_posture_errors
# ...

# %%
train_data_path = '../data/train'
columns_to_drop = ['image_filename', 'Nose_x', 'Nose_y', 'LEar_x', 'LEar_y', 'REar_x', 'REar_y']

for file_name in os.listdir(train_data_path):
    if file_name.endswith('.csv'):
        file_path = os.path.join(train_data_path, file_name)

        df = pd.read_csv(file_path)
        df = df.drop(columns=columns_to_drop, errors='ignore')

        df.to_csv(file_path, index=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[36], line 8
#       5 if file_name.endswith('.csv'):
#       6     file_path = os.path.join(train_data_path, file_name)
# ----> 8     df = pd.read_csv(file_path)
#       9     df = df.drop(columns=columns_to_drop, errors='ignore')
#      11     df.to_csv(file_path, index=False)
#
# ...

# %%
import pandas as pd
train_data_path = '../data/train'
df =pd.read_csv(f'{train_data_path}/chest_and_hip_joint_errors@CI02_Motion2-5.csv')
df.columns
# Out:
# Index(['LEye_x', 'LEye_y', 'REye_x', 'REye_y', 'LShoulder_x', 'LShoulder_y',
#        'RShoulder_x', 'RShoulder_y', 'LElbow_x', 'LElbow_y', 'RElbow_x',
#        'RElbow_y', 'LWrist_x', 'LWrist_y', 'RWrist_x', 'RWrist_y', 'LHip_x',
#        'LHip_y', 'RHip_x', 'RHip_y', 'LKnee_x', 'LKnee_y', 'RKnee_x',
#        'RKnee_y', 'LAnkle_x', 'LAnkle_y', 'RAnkle_x', 'RAnkle_y', 'Head_x',
#        'Head_y', 'Neck_x', 'Neck_y', 'Hip_x', 'Hip_y', 'LBigToe_x',
#        'LBigToe_y', 'RBigToe_x', 'RBigToe_y', 'LSmallToe_x', 'LSmallToe_y',
#        'RSmallToe_x', 'RSmallToe_y', 'LHeel_x', 'LHeel_y', 'RHeel_x',
#        'RHeel_y'],
#       dtype='object')

# %%
import os

# 현재 작업 디렉토리 경로 확인
current_path = os.getcwd()
print("현재 경로:", current_path)
# Out:
# 현재 경로: /mnt/c/Users/junun/documents/projects/src

# %%
import pandas as pd
import os

# train_data_path의 절대 경로를 사용하여 파일 경로 생성
train_data_path = os.path.abspath('../data/train')
file_path = os.path.join(train_data_path, 'chest_and_hip_joint_errors@CI02_Motion2-5.csv')

print("파일 경로:", file_path)

# 파일이 존재하는지 확인 후 읽기
if os.path.exists(file_path):
    df = pd.read_csv(file_path)
    print(df.columns)
else:
    print("파일이 존재하지 않습니다:", file_path)
# Out:
# 파일 경로: /mnt/c/Users/junun/documents/projects/data/train/chest_and_hip_joint_errors@CI02_Motion2-5.csv
# 파일이 존재하지 않습니다: /mnt/c/Users/junun/documents/projects/data/train/chest_and_hip_joint_errors@CI02_Motion2-5.csv

# %%
import os

# 현재 작업 디렉토리 경로 확인
current_path = os.getcwd()
print("현재 경로:", current_path)
# Out:
# 현재 경로: /mnt/c/Users/junun/documents/projects/src

# %%
import pandas as pd
import os

# 데이터 경로와 제거할 열 목록 설정
train_data_path = '../data/train'
columns_to_drop = ['LEye_x', 'LEye_y', 'REye_x', 'REye_y']

# 각 파일을 순회하며 처리
for file_name in os.listdir(train_data_path):
    if file_name.endswith('.csv'):
        file_path = os.path.join(train_data_path, file_name)

        # 파일 경로 출력
        print(f"Processing file: {file_path}")
        
        try:
            # CSV 파일 불러오기
            df = pd.read_csv(file_path)
            print(f"Columns before drop: {df.columns.tolist()}")  # 열 확인

            # 지정된 열 제거
            df = df.drop(columns=columns_to_drop, errors='ignore')
            print(f"Columns after drop: {df.columns.tolist()}")  # 열 확인

            # 동일한 경로에 저장
            df.to_csv(file_path, index=False)
            print(f"File saved successfully: {file_path}\n")

        except FileNotFoundError as e:
            print(f"FileNotFoundError: 파일을 찾을 수 없습니다 - {file_path}")
        except Exception as e:
            print(f"Error processing file {file_path}: {e}")
# Out:
# Processing file: ../data/train/arm_posture_errors@CA01_Motion2-1.csv
# Columns before drop: ['LEye_x', 'LEye_y', 'REye_x', 'REye_y', 'LShoulder_x', 'LShoulder_y', 'RShoulder_x', 'RShoulder_y', 'LElbow_x', 'LElbow_y', 'RElbow_x', 'RElbow_y', 'LWrist_x', 'LWrist_y', 'RWrist_x', 'RWrist_y', 'LHip_x', 'LHip_y', 'RHip_x', 'RHip_y', 'LKnee_x', 'LKnee_y', 'RKnee_x', 'RKnee_y', 'LAnkle_x', 'LAnkle_y', 'RAnkle_x', 'RAnkle_y', 'Head_x', 'Head_y', 'Neck_x', 'Neck_y', 'Hip_x', 'Hip_y', 'LBigToe_x', 'LBigToe_y', 'RBigToe_x', 'RBigToe_y', 'LSmallToe_x', 'LSmallToe_y', 'RSmallToe_x', 'RSmallToe_y', 'LHeel_x', 'LHeel_y', 'RHeel_x', 'RHeel_y']
# ...

# %%
train_data_path = '../data/train'
df =pd.read_csv(f'{train_data_path}/chest_and_hip_joint_errors@CI02_Motion2-5.csv')
df.columns
# Out:
# Index(['LEye_x', 'LEye_y', 'REye_x', 'REye_y', 'LShoulder_x', 'LShoulder_y',
#        'RShoulder_x', 'RShoulder_y', 'LElbow_x', 'LElbow_y', 'RElbow_x',
#        'RElbow_y', 'LWrist_x', 'LWrist_y', 'RWrist_x', 'RWrist_y', 'LHip_x',
#        'LHip_y', 'RHip_x', 'RHip_y', 'LKnee_x', 'LKnee_y', 'RKnee_x',
#        'RKnee_y', 'LAnkle_x', 'LAnkle_y', 'RAnkle_x', 'RAnkle_y', 'Head_x',
#        'Head_y', 'Neck_x', 'Neck_y', 'Hip_x', 'Hip_y', 'LBigToe_x',
#        'LBigToe_y', 'RBigToe_x', 'RBigToe_y', 'LSmallToe_x', 'LSmallToe_y',
#        'RSmallToe_x', 'RSmallToe_y', 'LHeel_x', 'LHeel_y', 'RHeel_x',
#        'RHeel_y'],
#       dtype='object')

# %%
train_data_path = '../data/train'
df = pd.read_csv(f'{train_data_path}/normal@CI09_Motion2-6 - 2of4.csv')
df.head(5)
# Out:
#        LEye_x      LEye_y      REye_x      REye_y  LShoulder_x  LShoulder_y  \
# 0  951.369080  184.893448  951.369080  184.893448   954.663452   234.309006
# 1  951.695007  185.100098  951.695007  185.100098   954.980408   234.380341
# 2  951.444946  185.311249  951.444946  185.311249   954.736694   234.687454
# 3  951.100952  184.686844  951.100952  184.686844   954.413086   234.368210
# 4  950.727478  184.281342  950.727478  187.602829   957.370483   234.103577
#
#    RShoulder_x  RShoulder_y    LElbow_x    LElbow_y  ...   RBigToe_x  \
# 0  1004.078979   227.720261  944.780334  287.018921  ...  977.723999
# 1  1000.975281   227.809647  945.124329  286.945953  ...  977.977844
# 2  1004.112915   228.103958  944.861450  287.355408  ...  977.778931
# 3  1004.094421   227.744034  944.476807  287.361664  ...  977.597717
# 4  1003.871216   227.460602  944.084534  287.247284  ...  977.299377
#
#     RBigToe_y  LSmallToe_x  LSmallToe_y  RSmallToe_x  RSmallToe_y     LHeel_x  \
# ...

# %%
df.columns
# Out:
# Index(['LEye_x', 'LEye_y', 'REye_x', 'REye_y', 'LShoulder_x', 'LShoulder_y',
#        'RShoulder_x', 'RShoulder_y', 'LElbow_x', 'LElbow_y', 'RElbow_x',
#        'RElbow_y', 'LWrist_x', 'LWrist_y', 'RWrist_x', 'RWrist_y', 'LHip_x',
#        'LHip_y', 'RHip_x', 'RHip_y', 'LKnee_x', 'LKnee_y', 'RKnee_x',
#        'RKnee_y', 'LAnkle_x', 'LAnkle_y', 'RAnkle_x', 'RAnkle_y', 'Head_x',
#        'Head_y', 'Neck_x', 'Neck_y', 'Hip_x', 'Hip_y', 'LBigToe_x',
#        'LBigToe_y', 'RBigToe_x', 'RBigToe_y', 'LSmallToe_x', 'LSmallToe_y',
#        'RSmallToe_x', 'RSmallToe_y', 'LHeel_x', 'LHeel_y', 'RHeel_x',
#        'RHeel_y'],
#       dtype='object')

# %%
len(df)
# Out:
# 385

# %%
import pandas as pd
import os

# 데이터 경로와 제거할 열 목록 설정
val_data_path = '../data/val'
columns_to_drop = ['LEye_x', 'LEye_y', 'REye_x', 'REye_y']

# 각 파일을 순회하며 처리
for file_name in os.listdir(val_data_path):
    if file_name.endswith('.csv'):
        file_path = os.path.join(val_data_path, file_name)

        # 파일 경로 출력
        print(f"Processing file: {file_path}")
        
        try:
            # CSV 파일 불러오기
            df = pd.read_csv(file_path)
            print(f"Columns before drop: {df.columns.tolist()}")  # 열 확인

            # 지정된 열 제거
            df = df.drop(columns=columns_to_drop, errors='ignore')
            print(f"Columns after drop: {df.columns.tolist()}")  # 열 확인

            # 동일한 경로에 저장
            df.to_csv(file_path, index=False)
            print(f"File saved successfully: {file_path}\n")

        except FileNotFoundError as e:
            print(f"FileNotFoundError: 파일을 찾을 수 없습니다 - {file_path}")
        except Exception as e:
            print(f"Error processing file {file_path}: {e}")
# Out:
# Processing file: ../data/val/arm_posture_errors@CA02_Motion2-1.csv
# Columns before drop: ['LEye_x', 'LEye_y', 'REye_x', 'REye_y', 'LShoulder_x', 'LShoulder_y', 'RShoulder_x', 'RShoulder_y', 'LElbow_x', 'LElbow_y', 'RElbow_x', 'RElbow_y', 'LWrist_x', 'LWrist_y', 'RWrist_x', 'RWrist_y', 'LHip_x', 'LHip_y', 'RHip_x', 'RHip_y', 'LKnee_x', 'LKnee_y', 'RKnee_x', 'RKnee_y', 'LAnkle_x', 'LAnkle_y', 'RAnkle_x', 'RAnkle_y', 'Head_x', 'Head_y', 'Neck_x', 'Neck_y', 'Hip_x', 'Hip_y', 'LBigToe_x', 'LBigToe_y', 'RBigToe_x', 'RBigToe_y', 'LSmallToe_x', 'LSmallToe_y', 'RSmallToe_x', 'RSmallToe_y', 'LHeel_x', 'LHeel_y', 'RHeel_x', 'RHeel_y']
# ...

# %% [markdown]
# for file_name in os.listdir(train_data_path):
#     if file_name.endswith('.csv'):
#         file_path = os.path.join(train_data_path, file_name)
#
#         # 파일 경로 출력
#         print(f" file: {file_path}")

# %% [markdown]
# Index(['LEye_x', 'LEye_y', 'REye_x', 'REye_y', 'LShoulder_x', 'LShoulder_y',
#        'RShoulder_x', 'RShoulder_y', 'LElbow_x', 'LElbow_y', 'RElbow_x',
#        'RElbow_y', 'LWrist_x', 'LWrist_y', 'RWrist_x', 'RWrist_y', 'LHip_x',
#        'LHip_y', 'RHip_x', 'RHip_y', 'LKnee_x', 'LKnee_y', 'RKnee_x',
#        'RKnee_y', 'LAnkle_x', 'LAnkle_y', 'RAnkle_x', 'RAnkle_y', 'Head_x',
#        'Head_y', 'Neck_x', 'Neck_y', 'Hip_x', 'Hip_y', 'LBigToe_x',
#        'LBigToe_y', 'RBigToe_x', 'RBigToe_y', 'LSmallToe_x', 'LSmallToe_y',
#        'RSmallToe_x', 'RSmallToe_y', 'LHeel_x', 'LHeel_y', 'RHeel_x',
#        'RHeel_y'],
#       dtype='object')

# %%
import matplotlib.pyplot as plt

df = pd.read_csv(f'{train_data_path}/normal@CI09_Motion2-3 - 4of4.csv')
# 관절 연결 관계 설정
connections = [
    ('Head', 'Neck'), 
    ('Neck', 'LShoulder'), ('Neck', 'RShoulder'),
    ('LShoulder', 'LElbow'), ('RShoulder', 'RElbow'),
    ('LElbow', 'LWrist'), ('RElbow', 'RWrist'),
    ('Neck', 'Hip'),
    ('Hip', 'LKnee'), ('Hip', 'RKnee'),
    ('LKnee', 'LAnkle'), ('RKnee', 'RAnkle')
]

# 삼각형 연결 관계 설정
triangle_connections = [
    ('LBigToe', 'LSmallToe'), ('LSmallToe', 'LHeel'), ('LHeel', 'LBigToe'),
    ('RBigToe', 'RSmallToe'), ('RSmallToe', 'RHeel'), ('RHeel', 'RBigToe')
]

# 첫 번째 프레임에 대해 스켈레톤 시각화
i = 0  # 첫 번째 프레임 선택
fig, ax = plt.subplots()

# 각 연결 관계에 따라 선 그리기
for point1, point2 in connections:
    try:
        x_values = [df[f'{point1}_x'][i], df[f'{point2}_x'][i]]
        y_values = [df[f'{point1}_y'][i], df[f'{point2}_y'][i]]
        ax.plot(x_values, y_values, marker='o')
        
        # 각 포인트에 이름 표시
        ax.text(df[f'{point1}_x'][i], df[f'{point1}_y'][i], point1, fontsize=8, ha='right')
        ax.text(df[f'{point2}_x'][i], df[f'{point2}_y'][i], point2, fontsize=8, ha='right')
    except KeyError:
        print(f"'{point1}' or '{point2}' column not found in the data.")
        continue

# 삼각형 그리기 및 Ankle 연결
for side in ['L', 'R']:
    try:
        # 삼각형 꼭짓점 좌표
        big_toe = (df[f'{side}BigToe_x'][i], df[f'{side}BigToe_y'][i])
        small_toe = (df[f'{side}SmallToe_x'][i], df[f'{side}SmallToe_y'][i])
        heel = (df[f'{side}Heel_x'][i], df[f'{side}Heel_y'][i])
        
        # 삼각형 그리기
        ax.plot([big_toe[0], small_toe[0]], [big_toe[1], small_toe[1]], 'b-')
        ax.plot([small_toe[0], heel[0]], [small_toe[1], heel[1]], 'b-')
        ax.plot([heel[0], big_toe[0]], [heel[1], big_toe[1]], 'b-')
        
        # Ankle 위치
        ankle = (df[f'{side}Ankle_x'][i], df[f'{side}Ankle_y'][i])
        
        # Ankle을 삼각형의 각 꼭짓점과 연결
        ax.plot([ankle[0], big_toe[0]], [ankle[1], big_toe[1]], 'b-', marker='o')
        ax.plot([ankle[0], small_toe[0]], [ankle[1], small_toe[1]], 'b-', marker='o')
        ax.plot([ankle[0], heel[0]], [ankle[1], heel[1]], 'b-', marker='o')
        
        # Ankle, BigToe, SmallToe, Heel에 이름 표시
        ax.text(ankle[0], ankle[1], f'{side}Ankle', fontsize=8, ha='right')
        ax.text(big_toe[0], big_toe[1], f'{side}BigToe', fontsize=8, ha='right')
        ax.text(small_toe[0], small_toe[1], f'{side}SmallToe', fontsize=8, ha='right')
        ax.text(heel[0], heel[1], f'{side}Heel', fontsize=8, ha='right')
        
    except KeyError:
        print(f"'{side}BigToe', '{side}SmallToe', '{side}Heel', or '{side}Ankle' column not found in the data.")
        continue

# 그래프 설정
ax.invert_yaxis()  # y축 뒤집기 (시각화 필요에 따라 조정)
plt.title("Skeleton Visualization - Frame 1")
plt.show()

# %%
for file_name in os.listdir(train_data_path):
    if file_name.endswith('.csv'):
        file_path = os.path.join(train_data_path, file_name)

    print(file_path)
# Out:
# ../data/train/arm_posture_errors@CA01_Motion2-1.csv
# ../data/train/arm_posture_errors@CA01_Motion2-2.csv
# ../data/train/arm_posture_errors@CA01_Motion2-3.csv
# ../data/train/arm_posture_errors@CA01_Motion2-4.csv
# ../data/train/arm_posture_errors@CA01_Motion2-5.csv
# ../data/train/arm_posture_errors@CA01_Motion2-6.csv
# ../data/train/arm_posture_errors@CA01_Motion2-7.csv
# ../data/train/arm_posture_errors@CA01_Motion2-8.csv
# ../data/train/arm_posture_errors@CA02_Motion2-1.csv
# ../data/train/arm_posture_errors@CA02_Motion2-2.csv
# ../data/train/arm_posture_errors@CA02_Motion2-3.csv
# ../data/train/arm_posture_errors@CA02_Motion2-4.csv
# ../data/train/arm_posture_errors@CA02_Motion2-5.csv
# ../data/train/arm_posture_errors@CA02_Motion2-6.csv
# ../data/train/arm_posture_errors@CA02_Motion2-7.csv
# ../data/train/arm_posture_errors@CA02_Motion2-8.csv
# ../data/train/arm_posture_errors@CA03_Motion2-1.csv
# ../data/train/arm_posture_errors@CA03_Motion2-2.csv
# ...

# %%
from matplotlib.animation import FuncAnimation

df = pd.read_csv(f'{train_data_path}/normal@CI09_Motion2-3 - 4of4.csv')

# 관절 연결 관계 설정
connections = [
    ('Head', 'Neck'), 
    ('Neck', 'LShoulder'), ('Neck', 'RShoulder'),
    ('LShoulder', 'LElbow'), ('RShoulder', 'RElbow'),
    ('LElbow', 'LWrist'), ('RElbow', 'RWrist'),
    ('Neck', 'Hip'),
    ('Hip', 'LKnee'), ('Hip', 'RKnee'),
    ('LKnee', 'LAnkle'), ('RKnee', 'RAnkle')
]

# 삼각형 연결 관계 설정
triangle_connections = [
    ('LBigToe', 'LSmallToe'), ('LSmallToe', 'LHeel'), ('LHeel', 'LBigToe'),
    ('RBigToe', 'RSmallToe'), ('RSmallToe', 'RHeel'), ('RHeel', 'RBigToe')
]

# 애니메이션 초기 설정
fig, ax = plt.subplots()
plt.title("Deadlift")
ax.invert_yaxis()  # y축 뒤집기

# 프레임 초기화 함수
def init():
    ax.clear()
    plt.title("Deadlift")
    ax.invert_yaxis()  # y축 뒤집기

# 각 프레임 업데이트 함수
def update(frame):
    ax.clear()  # 이전 프레임 지우기
    plt.title("Deadlift")
    ax.invert_yaxis()  # y축 뒤집기

    # 각 연결 관계에 따라 선 그리기
    for point1, point2 in connections:
        try:
            x_values = [df[f'{point1}_x'][frame], df[f'{point2}_x'][frame]]
            y_values = [df[f'{point1}_y'][frame], df[f'{point2}_y'][frame]]
            ax.plot(x_values, y_values, marker='o')
        except KeyError:
            continue

    # 삼각형 그리기 및 Ankle 연결
    for side in ['L', 'R']:
        try:
            # 삼각형 꼭짓점 좌표
            big_toe = (df[f'{side}BigToe_x'][frame], df[f'{side}BigToe_y'][frame])
            small_toe = (df[f'{side}SmallToe_x'][frame], df[f'{side}SmallToe_y'][frame])
            heel = (df[f'{side}Heel_x'][frame], df[f'{side}Heel_y'][frame])

            # 삼각형 그리기
            ax.plot([big_toe[0], small_toe[0]], [big_toe[1], small_toe[1]], 'b-')
            ax.plot([small_toe[0], heel[0]], [small_toe[1], heel[1]], 'b-')
            ax.plot([heel[0], big_toe[0]], [heel[1], big_toe[1]], 'b-')
            
            # Ankle 위치
            ankle = (df[f'{side}Ankle_x'][frame], df[f'{side}Ankle_y'][frame])

            # Ankle을 삼각형의 각 꼭짓점과 연결
            ax.plot([ankle[0], big_toe[0]], [ankle[1], big_toe[1]], 'b-', marker='o')
            ax.plot([ankle[0], small_toe[0]], [ankle[1], small_toe[1]], 'b-', marker='o')
            ax.plot([ankle[0], heel[0]], [ankle[1], heel[1]], 'b-', marker='o')
            
        except KeyError:
            continue

# 애니메이션 생성
ani = FuncAnimation(fig, update, frames=len(df), init_func=init, repeat=False)

# 애니메이션 저장
ani.save('skeleton_animation.mp4', writer='ffmpeg', fps=10)

# %%
df.head(5)
# Out:
#    LShoulder_x  LShoulder_y  RShoulder_x  RShoulder_y    LElbow_x    LElbow_y  \
# 0   850.752136   263.730316   805.695190   260.264404  857.684021  322.650940
# 1   850.503174   263.817505   805.372681   260.345917  857.446350  322.834290
# 2   850.667358   263.899261   805.360657   260.414124  857.637573  323.146484
# 3   850.463196   264.318024   805.482483   260.857941  857.383301  323.138977
# 4   850.833130   264.306976   805.971802   260.856110  857.734863  322.971771
#
#      RElbow_x    RElbow_y    LWrist_x    LWrist_y  ...   RBigToe_x  \
# 0  812.627014  319.185028  854.218079  371.173828  ...  809.161133
# 1  812.315857  319.362732  853.974792  371.436371  ...  808.844299
# 2  812.330933  319.661346  854.152466  371.938293  ...  808.845764
# 3  808.942505  319.678925  853.923279  375.039856  ...  808.942505
# 4  809.422668  319.520905  854.283997  374.734833  ...  805.971802
#
#     RBigToe_y  LSmallToe_x  LSmallToe_y  RSmallToe_x  RSmallToe_y     LHeel_x  \
# ...

# %%
df.columns
# Out:
# Index(['LShoulder_x', 'LShoulder_y', 'RShoulder_x', 'RShoulder_y', 'LElbow_x',
#        'LElbow_y', 'RElbow_x', 'RElbow_y', 'LWrist_x', 'LWrist_y', 'RWrist_x',
#        'RWrist_y', 'LHip_x', 'LHip_y', 'RHip_x', 'RHip_y', 'LKnee_x',
#        'LKnee_y', 'RKnee_x', 'RKnee_y', 'LAnkle_x', 'LAnkle_y', 'RAnkle_x',
#        'RAnkle_y', 'Head_x', 'Head_y', 'Neck_x', 'Neck_y', 'Hip_x', 'Hip_y',
#        'LBigToe_x', 'LBigToe_y', 'RBigToe_x', 'RBigToe_y', 'LSmallToe_x',
#        'LSmallToe_y', 'RSmallToe_x', 'RSmallToe_y', 'LHeel_x', 'LHeel_y',
#        'RHeel_x', 'RHeel_y'],
#       dtype='object')

# %%
import os
import glob
import shutil
from sklearn.model_selection import train_test_split

train_dir = '../data/train'
train_output_dir = '../data/train'
test_output_dir = '../data/test'

os.makedirs(train_output_dir, exist_ok=True)
os.makedirs(test_output_dir, exist_ok=True)

normal_files = glob.glob(os.path.join(train_dir, 'normal*.csv'))
error_files = glob.glob(os.path.join(train_dir, '*errors*.csv'))


normal_train_files, normal_test_files = train_test_split(normal_files, test_size=0.2, random_state=42)
error_train_files, error_test_files = train_test_split(error_files, test_size=0.2, random_state=42)

train_files = normal_train_files + error_train_files
test_files =normal_test_files+error_test_files

for file in train_files:
    shutil.copy(file, train_output_dir)
for file in test_files:
    shutil.copy(file, test_output_dir)

print(f"Training files: {len(train_files)}")
print(f"Testing files: {len(test_files)}")
# Out:
# Training files: 1778
# Testing files: 445

# %%
train_dir = '../data/train'

normal_files = glob.glob(os.path.join(train_dir, 'normal*.csv'))
error_files = glob.glob(os.path.join(train_dir, '*errors*.csv'))


# Counting files
normal_count = len(normal_files)
error_count = len(error_files)
total_count =normal_count + error_count
# 파일이 존재하는 경우에만 그래프 그리기
if normal_count > 0 or error_count > 0:
    # Pie chart data
    file_counts = [normal_count, error_count]
    labels = ['Normal', 'Error']

    # Plotting the pie chart
    plt.figure(figsize=(6, 6))
    plt.pie(file_counts, labels=labels, autopct='%1.1f%%', startangle=140)
    plt.title('train data')
    plt.show()
else:
    print("No files found in the specified directory.")
print(total_count)
# Out:
# 2223

# %%
test_dir = '../data/test'

normal_files = glob.glob(os.path.join(test_dir, 'normal*.csv'))
error_files = glob.glob(os.path.join(test_dir, '*errors*.csv'))


# Counting files
normal_count = len(normal_files)
error_count = len(error_files)
total_count =normal_count + error_count
# 파일이 존재하는 경우에만 그래프 그리기
if normal_count > 0 or error_count > 0:
    # Pie chart data
    file_counts = [normal_count, error_count]
    labels = ['Normal', 'Error']

    # Plotting the pie chart
    plt.figure(figsize=(6, 6))
    plt.pie(file_counts, labels=labels, autopct='%1.1f%%', startangle=140)
    plt.title('test data')
    plt.show()
else:
    print("No files found in the specified directory.")
print(total_count)
# Out:
# 445

# %%
df =pd.read_csv('/mnt/c/Users/junun/documents/projects/data/train/arm_posture_errors@CA01_Motion2-1.csv')


df
# Out:
#      LShoulder_x  LShoulder_y  RShoulder_x  RShoulder_y    LElbow_x  \
# 0     956.432251   396.035248  1071.601196   401.042603  941.410217
# 1     956.360718   396.922668  1071.394409   401.924133  941.356262
# 2     956.233765   395.225739  1071.753174   400.248322  941.166016
# 3     956.505188   396.758881  1071.468750   401.757294  941.509949
# 4     956.546509   396.070892  1071.638550   401.074890  941.534485
# ..           ...          ...          ...          ...         ...
# 258   955.552856   395.244110  1071.947632   400.304749  940.370911
# 259   955.300049   394.648285  1071.912476   399.718384  940.089722
# 260   955.235107   394.120483  1071.979736   399.196320  940.007568
# 261   955.181274   393.424835  1072.151001   398.510468  939.924377
# 262   955.091797   394.555481  1071.995972   399.638275  939.843445
#
#        LElbow_y     RElbow_x    RElbow_y    LWrist_x    LWrist_y  ...  \
# 0    476.152802  1086.623291  486.167480  941.410217  536.240967  ...
# ...
